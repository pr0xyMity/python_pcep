# %% [markdown]
# # Module 2: Data Types, Variables, Basic I/O, and Operators
#
# This notebook covers essential Python data types and operations for PCEP certification.
#
# ## Topics Covered:
# - Variables and naming conventions
# - Data types (int, float, str, bool)
# - Type conversion
# - Basic operators
# - User input

# %% [markdown]
# ## 2.1 Variables
#
# Variables are containers for storing data values.

# %%
# Creating variables
name = "Alice"
age = 25
height = 5.6
is_student = True

print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Student:", is_student)
# Out:
# Name: Alice
# Age: 25
# Height: 5.6
# Student: True

# %% [markdown]
# ### Variable Naming Rules:
# - Must start with a letter or underscore
# - Can contain letters, numbers, and underscores
# - Case-sensitive
# - Cannot use Python keywords

# %%
# Valid variable names
my_variable = 10
_private = 20
variable2 = 30

# Invalid variable names (commented out)
# 2variable = 40  # Cannot start with a number
# my-variable = 50  # Cannot use hyphens
# for = 60  # Cannot use keywords

# %% [markdown]
# ## 2.2 Data Types
#
# Python has several built-in data types:

# %%
# Integer (int)
x = 42
print("Integer:", x, "Type:", type(x))

# Float
y = 3.14
print("Float:", y, "Type:", type(y))

# String (str)
z = "Hello"
print("String:", z, "Type:", type(z))

# Boolean (bool)
w = True
print("Boolean:", w, "Type:", type(w))
# Out:
# Integer: 42 Type: <class 'int'>
# Float: 3.14 Type: <class 'float'>
# String: Hello Type: <class 'str'>
# Boolean: True Type: <class 'bool'>

# %% [markdown]
# ## 2.3 Type Conversion
#
# Converting between different data types:

# %%
# Integer to float
num = 10
float_num = float(num)
print("Float:", float_num)

# Float to integer (truncates decimal part)
decimal = 3.99
int_num = int(decimal)
print("Integer:", int_num)

# Number to string
value = 42
text = str(value)
print("String:", text, "Type:", type(text))

# String to number
text_num = "123"
number = int(text_num)
print("Number:", number)

# %% [markdown]
# ## 2.4 Arithmetic Operators
#
# Python supports standard arithmetic operations:

# %%
# Basic operations
a = 10
b = 3

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)  # Returns integer part
print("Modulus:", a % b)  # Returns remainder
print("Exponentiation:", a ** b)  # a to the power of b

# %% [markdown]
# ## 2.5 Comparison Operators
#
# Used to compare values, return True or False:

# %%
x = 10
y = 5

print("Equal:", x == y)
print("Not equal:", x != y)
print("Greater than:", x > y)
print("Less than:", x < y)
print("Greater or equal:", x >= y)
print("Less or equal:", x <= y)

# %% [markdown]
# ## 2.6 Logical Operators
#
# Used to combine conditional statements:

# %%
a = True
b = False

print("AND:", a and b)  # True if both are True
print("OR:", a or b)   # True if at least one is True
print("NOT:", not a)   # Inverts the boolean value

# %% [markdown]
# ## 2.7 User Input
#
# Getting input from the user:

# %%
# Basic input (returns string)
# Uncomment to test interactively
name = input("Enter your name: ")
print("Hello,", name)

# Converting input to number
age = int(input("Enter your age: "))
print("You are", age, "years old")
# Out:
# Enter your name:  Konrad
# Hello, Konrad
# Enter your age:  30
# You are 30 years old

# %% [markdown]
# ## 2.8 Practice Exercises

# %%
# Exercise 1: Create variables for your name, age, and favorite number
# TODO: Write code here
name = input("Enter your name")
age = int(input("Enter your age"))
favorite_number = float(input("Enter your favorite number"))
# Out:
# Enter your name Konrad
# Enter your age 30
# Enter your favorite number 3.14

# %%
# Exercise 2: Calculate the area of a rectangle (length=5, width=3)
# TODO: Write code here
def calculate_rectangle_area(length, width):
    return length*width;

print(calculate_rectangle_area(5,10))
# Out:
# 50

# %%
# Exercise 3: Convert temperature from Celsius to Fahrenheit
# Formula: F = (C * 9/5) + 32
# TODO: Write code here
def convert_temp_celsius_fahrenheit(celsius):
    return (celsius * 9/5) + 32

print(convert_temp_celsius_fahrenheit(100));
# Out:
# 212.0

# %%
# Exercise 4: Check if a number is even or odd using modulus operator
# TODO: Write code here
def isNumberEven(number):
    return number % 2 == 0;

print(isNumberEven(20));
# Out:
# True

# %% [markdown]
# ## Summary
#
# In this module, you learned:
# - How to create and name variables
# - Python's basic data types
# - Type conversion between data types
# - Arithmetic, comparison, and logical operators
# - How to get user input
#
# Continue to the next notebook to learn about control flow!

# %%
global_var = "I am global" # G

def outer_func():
    enclosing_var = "I am enclosing" # E
    def inner_func():
        local_var = "I am local" # L
        print(local_var)       # Prints "I am local" (L)
        print(enclosing_var)   # Prints "I am enclosing" (E)
        print(global_var)      # Prints "I am global" (G)
        # print(builtin_var) # Would fail if not a real builtin
    inner_func()

outer_func()
